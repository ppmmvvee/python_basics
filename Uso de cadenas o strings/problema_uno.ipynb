# %%
def imprimir_nombre_multiples_veces(nombre_usuario, numero):
    for _ in range(numero):
        print(nombre_usuario)

# Ejemplo de uso:
nombre = input("Ingrese su nombre: ")
veces = int(input("Ingrese un número entero: "))

imprimir_nombre_multiples_veces(nombre, veces)
