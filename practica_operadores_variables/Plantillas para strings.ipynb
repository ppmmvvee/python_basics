# %%
'%s, eggs, and %s' % ('spam', 'SPAM!')
# Out:
# 'spam, eggs, and SPAM!'

# %%
'{0}, eggs, and {1}'.format('spam', 'SPAM!')
# Out:
# 'spam, eggs, and SPAM!'

# %%
'{}, eggs, and {}'.format('spam', 'SPAM!')
# Out:
# 'spam, eggs, and SPAM!'

# %%
f'{S}, eggs, and {line}'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-11a266c42756> in <cell line: 1>()
# ----> 1 f'{S}, eggs, and {line}'
#
# NameError: name 'S' is not defined
