# %%
123 + 222
# Out:
# 345

# %%
1.5 * 4
# Out:
# 6.0

# %%
2 ** 100
# Out:
# 1267650600228229401496703205376

# %%
len(893)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-4-f417ea76a32e> in <cell line: 1>()
# ----> 1 len(893)
#
# TypeError: object of type 'int' has no len()

# %%
len("893")
# Out:
# 3

# %%
len([2, 3, 4, 5])
# Out:
# 4

# %%
len(str(2 ** 1000000))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-2-6d48a2a35d72> in <cell line: 1>()
# ----> 1 len(str(2 ** 1000000))
#
# ValueError: Exceeds the limit (4300) for integer string conversion; use sys.set_int_max_str_digits() to increase the limit

# %%
import math

# %%
Math.pi
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-baadc155911a> in <cell line: 1>()
# ----> 1 Math.pi
#
# NameError: name 'Math' is not defined

# %%
math.sqrt(85)
# Out:
# 9.219544457292887

# %%
import random

# %%
random.random()
# Out:
# 0.7064057070429954

# %%
random.choice([1, 2, 3, 4])
# Out:
# 4

# %%
st = 'Spam'

# %%
len(st)
# Out:
# 4

# %%
st[0]
# Out:
# 'S'

# %%
st[-1]
# Out:
# 'm'

# %%
st[1:3]
# Out:
# 'pa'

# %%
st[1:]
# Out:
# 'pam'

# %%
st[:]
# Out:
# 'Spam'

# %%
st + "Hola"
# Out:
# 'SpamHola'

# %%
st * 5
# Out:
# 'SpamSpamSpamSpamSpam'

# %%
st[0] = 'z'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-21-12992bd50d9b> in <cell line: 1>()
# ----> 1 st[0] = 'z'
#
# TypeError: 'str' object does not support item assignment

# %%
st = 'z' + st[1:]

# %%
print(st)
# Out:
# zpam
