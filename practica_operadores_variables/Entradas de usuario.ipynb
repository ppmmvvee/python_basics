# %%
color = input("Introduce el color de tu camisa?: ")
# Out:
# Introduce el color de tu camisa?: Blanco

# %%
print(color)
# Out:
# Blanco

# %%
n = int(input("Cuantas camisas tienes?: "))
# Out:
# Cuantas camisas tienes?: 1

# %%
print(n)
# Out:
# 1

# %%
price = float(input("Cuanto costo la mas bonita?: "))
# Out:
# Cuanto costo la mas bonita?: 799.99

# %%
print(price)
# Out:
# 799.99
