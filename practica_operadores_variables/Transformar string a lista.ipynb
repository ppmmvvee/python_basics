# %%
S = 'shrubbery'

# %%
L = list(S)

# %%
L
# Out:
# ['s', 'h', 'r', 'u', 'b', 'b', 'e', 'r', 'y']

# %%
L[1] = 'c'

# %%
''.join(L)
# Out:
# 'scrubbery'

# %%
B = bytearray(b'spam')

# %%
B.extend(b'eggs')

# %%
B
# Out:
# bytearray(b'spameggs')

# %%
B.decode()
# Out:
# 'spameggs'
