# %%
S = 'Spam'

# %%
S.find('pa')
# Out:
# 1

# %%
S
# Out:
# 'Spam'

# %%
S.replace('pa', 'XYZ')
# Out:
# 'SXYZm'

# %%
S
# Out:
# 'Spam'

# %%
line = 'aaa,bbb,ccccc,dd'

# %%
line.split(',')
# Out:
# ['aaa', 'bbb', 'ccccc', 'dd']

# %%
S = 'spam'

# %%
S.upper()
# Out:
# 'SPAM'

# %%
S.isalpha()
# Out:
# True

# %%
line = 'aaa,bbb,ccccc,dd\n'

# %%
line.rstrip()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-2e9b96d342df> in <cell line: 1>()
# ----> 1 line.rstrip()
#
# NameError: name 'line' is not defined

# %%
line.rstrip().split(',')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-848a50448abd> in <cell line: 1>()
# ----> 1 line.rstrip().split(',')
#
# NameError: name 'line' is not defined
