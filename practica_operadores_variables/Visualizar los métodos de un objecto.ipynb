# %%
dir(S) # S es un string
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-1-70baf3af12f6> in <cell line: 1>()
# ----> 1 dir(S) # S es un string
#
# NameError: name 'S' is not defined

# %%
help(S.replace)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-7e0cd2abfb42> in <cell line: 1>()
# ----> 1 help(S.replace)
#
# NameError: name 'S' is not defined

# %%
S = 'A\nB\tC'

# %%
len(S)
# Out:
# 5

# %%
ord('\n')
# Out:
# 10

# %%
S = 'A\0B\0C'

# %%
len(S)
# Out:
# 5

# %%
S
# Out:
# 'A\x00B\x00C'

# %%
msg = """
aaaaaaaaaaaaa
Strings | 105bbb'''bbbbbbbbbb""bbbbbbb'bbbb
cccccccccccccc
"""

# %%
msg
# Out:
# '\naaaaaaaaaaaaa\nStrings | 105bbb\'\'\'bbbbbbbbbb""bbbbbbb\'bbbb\ncccccccccccccc\n'
